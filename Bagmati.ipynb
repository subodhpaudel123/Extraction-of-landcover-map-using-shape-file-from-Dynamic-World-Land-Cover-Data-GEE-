# %%
import ee
import geopandas as gpd
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize(project='ee-subodhpaudel123')
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def export_dynamic_world(year,region,folder='Dynamicworldexports'):
  start_date= ee.Date.fromYMD(year,1,1)
  end_date= start_date.advance(1,'year')

  dw= ee.ImageCollection('GOOGLE/DYNAMICWORLD/V1') \
  .filterDate(start_date,end_date)\
  .filterBounds(region)\
  .median().clip(region)

  dw_image = dw.select('label').toInt()

  task= ee.batch.Export.image.toDrive(
      image= dw_image,
      description= f"Hetauda{year}",
      scale= 10,
      region=region,
      maxPixels=1e13,
      crs='EPSG:4326'
  )
  task.start()
  print(f"Exporting Dynamic World data for Hetauda {year} to Google Drive...")

gdf= gpd.read_file('/content/Hetauda.shp')
geo_json = gdf.__geo_interface__
region= ee.Geometry.Polygon(geo_json['features'][0]['geometry']['coordinates'])

years= [2016,2024]
for year in years:
  export_dynamic_world(year,region)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Exporting Dynamic World data for Hetauda 2016 to Google Drive...
# Exporting Dynamic World data for Hetauda 2024 to Google Drive...
